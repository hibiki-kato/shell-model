# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import math
import cmath
from numba import njit, f8,i8,c16
import numba
import matplotlib.animation as animation
from IPython.display import HTML
import copy

import sys
sys.path.append('../../lb')
import RungeKutta_acceralated

# %%
#パラメーター
nu = 0.001

f = (1 + 1j) * 5 * 0.001

Dimention = 12 #uの次元数
q = 2
k_0 = 2 ** (-4)
k_n = np.zeros((Dimention+4,1))
k_n[2:-2,0] = [k_0 * q ** (i+1) for i in range(Dimention)]
#print(k_n)

c_n_1 = copy.deepcopy(k_n)[2:-2, 0:]
c_n_1[-2:, 0:] = np.zeros((2,1))
#print(c_n_1)

beta = 0.5
c_n_2 = copy.deepcopy(k_n)[1:-3, 0:] * -beta
c_n_2[-1, 0] = np.zeros((1, 1))
#print(c_n_2)

c_n_3 = copy.deepcopy(k_n)[:-4, 0:] * (beta - 1)
#print(c_n_3)

#parameter = [nu,f,k_n,c_n_1,c_n_2,c_n_3]
parameter = {
    'nu' : nu,
    'f' : f,
    'k_n' : k_n,
    'c_n_1' : c_n_1,
    'c_n_2' : c_n_2,
    'c_n_3' : c_n_3
}
#print(parameter)
#print(k_n)

# %%
runge_para = {
    'start' :  np.array([
        [0.4350E+00 + 0.5008E+00j],
        [0.1259E+00 + 0.2437E+00j],
        [-0.8312E-01 + -0.4802E-01j],
        [0.5164E-01 + -0.1599E+00j],
        [-0.1899E+00 + -0.3602E-01j],
        [0.4093E-03 + 0.8506E-01j],
        [0.9539E-01 + 0.3215E-01j],
        [-0.5834E-01 + 0.4433E-01j],
        [-0.8790E-02 + 0.2502E-01j],
        [0.3385E-02 + 0.1148E-02j],
        [-0.7072E-04 + 0.5598E-04j],
        [-0.5238E-07 + 0.1467E-06j]
    ]),
    'step' : 0.005,
    'period' : (0,1500),
    'nu' : nu,
    'f' : f,
    'k_n' : k_n,
    'c_n_1' : c_n_1,
    'c_n_2' : c_n_2,
    'c_n_3' : c_n_3,
}

# %%
begin = 3.6
end = 4.2
param_step = 500

param = np.linspace(begin,end,param_step) 

step_number = int((runge_para["period"][1] - runge_para["period"][0]) // runge_para["step"]) + 1
param_size = len(param)
#print(step_number)
cascade_tensor = np.zeros((param_size,len(runge_para["start"])+1,step_number), dtype = "complex128")

#インスタンス化
model = RungeKutta_acceralated.RungeKutta()

for i, number in enumerate(tqdm(param)):
    #betaの値に従いc_n_2,c_n_3を更新
    #c_n_2
    runge_para["c_n_2"] = runge_para["k_n"][1:-3, 0:] * -number
    runge_para["c_n_2"][-1, 0] = np.zeros((1, 1))
    
    #c_n_3
    runge_para["c_n_3"] = runge_para["k_n"][:-4, 0:] * (number - 1)
    
    model.get_arr(**runge_para)
    cascade_tensor[i] = model.arr
# Out:
# 100%|█████████████████████████████████████████| 500/500 [22:22<00:00,  2.68s/it]

# %%
@njit(f8[:](c16[:,:],i8,i8,f8[:]),cache=True)
def loc_max_7(arr,step_number,kaishi,z_list):
    for j in range(len(arr[0,-kaishi:])- 3):
        #7点とって極大判定
        if (    abs(arr[3,j-kaishi+1]) - abs(arr[3,j-kaishi]) > 0
            and abs(arr[3,j-kaishi+2]) - abs(arr[3,j-kaishi+1]) > 0
            and abs(arr[3,j-kaishi+3]) - abs(arr[3,j-kaishi+2]) > 0
            and abs(arr[3,j-kaishi+4]) - abs(arr[3,j-kaishi+3]) < 0
            and abs(arr[3,j-kaishi+5]) - abs(arr[3,j-kaishi+4]) < 0
            and abs(arr[3,j-kaishi+6]) - abs(arr[3,j-kaishi+5]) < 0):
            z_list = np.append(z_list,abs(arr[4,j-kaishi+3]))
    return z_list

# %%
# u_5(u_4が極大値)を抽出
latter_candidates = [50,20,10,4]
for latter in latter_candidates:
    kaishi = step_number // latter
    plt.figure(dpi=300)
    #plt.title(f"dimention:{len(cascade_tensor[0,:-1,0])} \n step:{runge_para['step']} \n period:{runge_para['period']} \n param_step:{len(param)} \n latter{round(kaishi/step_number,2)}", y = 0.5, x = 0.9)
    #plt.yscale("log")
    plt.xlabel("beta")
    plt.ylabel("|u5|")
    for i  in tqdm(range(len(param))):
        z_list=np.array([],dtype=np.float64) #u4極大値の時のu5を入れる空のリスト
        plt.scatter([param[i]]*len(loc_max_7(cascade_tensor[i],step_number,kaishi,z_list)),loc_max_7(cascade_tensor[i],step_number,kaishi,z_list),s=0.1)

    plt.savefig(fname=f"beta_pdf/beta({param[0]},{param[-1]})_{runge_para['step']}_{runge_para['period']}_{len(param)}cut_{Dimention}dim_latter{round(kaishi/step_number,2)}.png")
# Out:
# 100%|████████████████████████████████████████| 500/500 [00:02<00:00, 232.59it/s]

# %% [markdown]
# fig = plt.figure(dpi=300)
# ims = []
#
# for i in tqdm(range(400)):
#     im = plt.plot(abs(cascade_tensor[i,-1,:]),abs(cascade_tensor[i,3,:]),color="b",lw=0.1)
#     ims.append(im)
#
# anim = animation.ArtistAnimation(fig, ims)
# HTML(anim.to_jshtml())
